# %%
import numpy as np
import plotly.graph_objects as go
import scipy.stats as stats

# %%
n = 100
plot_bgcolor_ ='rgba(0,0,0,0)'
showline_color = 'rgb(105,118,158)'
hist_color = 'rgb(246,192,150)'

# %%
tr = np.random.triangular(0, 1, 1, n)
no = np.random.normal(0.5, 1, n)
lg = np.random.lognormal(0.0009,1, n)

# %%
option = 'tr'
if option == 'no':
    data = no
    mu, sigma = stats.norm.fit(data)
    x = np.linspace(min(data), max(data), n)
    y = stats.norm.pdf(x, mu, sigma)
elif option == 'lg':
    data = lg
    shape,loc,scale = stats.lognorm.fit(data)
    x = np.linspace(min(data), max(data), n)
    y = stats.lognorm.pdf(x, shape,loc,scale)
elif option == 'tr':
    data = tr
    a,b,c = stats.triang.fit(data)
    x = np.linspace(min(data), max(data), n)
    y = stats.triang.pdf(x, a,b,c)

# %%
wd = 10
fig = go.Figure()
fig.add_trace(go.Histogram(
    x=data,
    nbinsx=40,
    marker_color=hist_color,
    histnorm='probability density',
))
fig.add_trace(go.Scatter(
    x=x,
    y=y, 
    marker_color = showline_color,
    line_width=wd,
))
fig.update_layout(height=600, 
                  width=600, 
                  plot_bgcolor=plot_bgcolor_,
                  paper_bgcolor=plot_bgcolor_,
                  xaxis_showgrid=False, 
                  yaxis_showgrid=False,
                  showlegend=False
                 )

fig.update_xaxes(tickvals = [],
                 showline=False, 
                 linewidth=wd, 
                 linecolor=showline_color,
                 zeroline=False,
                 zerolinecolor=showline_color,
                 zerolinewidth=wd)
fig.update_yaxes(tickvals = [],
                 showline=False, 
                 linewidth=wd, 
                 linecolor=showline_color,
                 zeroline=True,
                 zerolinecolor=showline_color,
                 zerolinewidth=wd)
    
fig.show()

fig.write_image(option + '.pdf')
# Out:
# <div>
#
#
#             <div id="8c54b793-62db-42e8-9cca-9268ad31a41b" class="plotly-graph-div" style="height:600px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8c54b793-62db-42e8-9cca-9268ad31a41b")) {
#                     Plotly.newPlot(
#                         '8c54b793-62db-42e8-9cca-9268ad31a41b',
#                         [{"histnorm": "probability density", "marker": {"color": "rgb(246,192,150)"}, "nbinsx": 40, "type": "histogram", "x": [0.8499068607598419, 0.30299772540564757, 0.7705936092306949, 0.4701524044968675, 0.6264964805088789, 0.05572804808140399, 0.419796106835233, 0.8527342862234593, 0.5060637383205698, 0.9657559316371543, 0.9073079196720295, 0.6834351449385488, 0.2625429438343718, 0.9504065765567189, 0.7866984569141068, 0.28070874131573686, 0.4971281160475148, 0.5118760217863404, 0.5480664883756013, 0.7013370749018214, 0.6906022805978822, 0.9880371786361958, 0.30421277664093244, 0.506873865213181, 0.9668301375076738, 0.4040483518306186, 0.2503244234095921, 0.8009874904452015, 0.9899440450289422, 0.6686254125392663, 0.8154786047102555, 0.9097528959265486, 0.9393563153816451, 0.8355837381550829, 0.7053612925188866, 0.7384208400925583, 0.4286022347353157, 0.7994912771986402, 0.8165958718188645, 0.15636308438210914, 0.7040409526739447, 0.936891818619345, 0.7017484134103594, 0.7595467340806054, 0.9487554332946733,